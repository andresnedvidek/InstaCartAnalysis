# %% [markdown]
# ## CareerFoundry Task 4.5

# %%
#Import Libaries/ Import the pandas, NumPy
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Task 1

# %%
path = r'/Users/andrenedvidek/Desktop/Data Analaysis/CareerFoundry /Data Emersion /Task 4.3/02 Data copy/Prepared Data'

# %%
path_2 = r'/Users/andrenedvidek/Desktop/Data Analaysis/CareerFoundry /Data Emersion /Task 4.3/02 Data copy/Original Data'

# %%
#import Data 
df_ords = pd.read_csv(os.path.join(path, 'orders_wrangled.csv'), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path_2, 'products.csv'), index_col = False)

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
#creat a datafram
df_test = pd.DataFrame()

# %%
#fill created datadram with mixed datatyps be filling it with different kind of data
df_test ['mix'] = ['a','b',1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Searching for mixed datatypes
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# /var/folders/sb/vky803ms4yqcv95cvw9hmntr0000gn/T/ipykernel_15656/3908776505.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# creating a new datafram with only the missing values in the df_prods datafram 
df_nan = df_prods[df_prods['product_name'].isnull()==True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# looking at the number of rows and columns
df_prods.shape
# Out:
# (49693, 5)

# %%
# creating a new datafram but thistime filtering out the missing values isntead of before only keeping the missing values
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# searching the datafrmae df_prods_clean for duplicate rows
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
#there are 5 duplicate rows

# %%
# now dropping all duplicate rows and saving that new data in a new data frame
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
#down three rows which makes sence

# %%
#saving cleaned data 
df_prods_clean_no_dups.to_csv(os.path.join(path,'products_checked.csv'))

# %% [markdown]
# ## Task 2

# %%
# Task for Sumbmission from now on 
# task 2
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# #### user_id has less uniqe identifiers

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     NaN
# 1                         3                  7                    15.0
# ...

# %%
# I have somehow added two columns to the data frame and must now drop them
df_ords_drop = df_ords.drop(columns=['Unnamed: 0'])

# %%
print(df_ords.columns)
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'eval_set', 'order_number',
#        'orders_day_of_week', 'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df_ords_drop
# Out:
#          order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329        1    prior             1                   2
# 1         2398795        1    prior             2                   3
# 2          473747        1    prior             3                   3
# 3         2254736        1    prior             4                   4
# 4          431534        1    prior             5                   4
# ...           ...      ...      ...           ...                 ...
# 3421078   2266710   206209    prior            10                   5
# 3421079   1854736   206209    prior            11                   4
# 3421080    626363   206209    prior            12                   1
# 3421081   2977660   206209    prior            13                   1
# 3421082    272231   206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %% [markdown]
# ## Task 3

# %%
# task 3. Searching for mixed datatypes
for col in df_ords_drop.columns.tolist():
  weird = (df_ords_drop[[col]].map(type) != df_ords_drop[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords_drop[weird]) > 0:
    print (col)

# %%
# we can tell that 
# Searching for mixed data types
weird = (df_ords_drop[[col]].map(type) != df_ords_drop[[col]].iloc[0].map(type)).any(axis=1)

# %%
weird
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3421078    False
# 3421079    False
# 3421080    False
# 3421081    False
# 3421082    False
# Length: 3421083, dtype: bool

# %% [markdown]
# #### I cant say if I might of done something wrong. However I assume that none of the columns have mix data

# %% [markdown]
# ## Task 4

# %% [markdown]
# #### cant be completed due to no mixed data I think

# %% [markdown]
# ## Task 5

# %%
#Run a check for missing values in your df_ords data frame
df_ords_drop.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# ### There is no missing data except for in column days_since_prior_order
# ### explanation: I believe this represents customers who do not yet have a prior order

# %% [markdown]
# ## Task 6

# %% [markdown]
# ### I Cant delete the missing values because they are not really missing in the sense that data should be there
# ### thus the missing data is telling a story
# ### Best to import the missing values into a new data frame for further analysis

# %%
df_one_time_customers = df_ords_drop[df_ords_drop['days_since_prior_order'].isnull()]

# %%
df_one_time_customers
# Out:
#          order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329        1    prior             1                   2
# 11        2168274        2    prior             1                   2
# 26        1374495        3    prior             1                   1
# 39        3343014        4    prior             1                   6
# 45        2717275        5    prior             1                   3
# ...           ...      ...      ...           ...                 ...
# 3420930    969311   206205    prior             1                   4
# 3420934   3189322   206206    prior             1                   3
# 3421002   2166133   206207    prior             1                   6
# 3421019   2227043   206208    prior             1                   1
# 3421069   3154581   206209    prior             1                   3
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
df_one_time_customers['order_number'].value_counts()
# Out:
# order_number
# 1    206209
# Name: count, dtype: int64

# %% [markdown]
# ## Task 7

# %%
# finding duplicates
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_ords_drop_out_dub = df_ords_drop[df_ords_drop.duplicated()]

# %%
df_ords_drop_out_dub
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# ### Looks like there are no Dublicates

# %% [markdown]
# ## Task 8

# %%
# task 8
#  it seems that there are no duplicates

# %% [markdown]
# ## Task 9

# %%
# task 9 saving the files
df_ords_drop.to_csv(os.path.join(path,'orders_checked.csv'))

# %% [markdown]
# ### Saved df_prods in task 1
