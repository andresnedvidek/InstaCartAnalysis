# %% [markdown]
# ## CareerFoundry Task 4.4

# %% [markdown]
# ## Task 2

# %%
#Import Libaries/ Import the pandas, NumPy
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/andrenedvidek/Desktop/Data Analaysis/CareerFoundry /Data Emersion /Task 4.3/02 Data copy/Prepared Data'

# %%
path_2 = r'/Users/andrenedvidek/Desktop/Data Analaysis/CareerFoundry /Data Emersion /Task 4.3/02 Data copy/Original Data'

# %%
df_ords = pd.read_csv(os.path.join(path_2, 'orders.csv'), index_col = False)

# %%
df_ords.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# Task.2
# I can see that user_id does not need to be int and I will change it to string 
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords.dtypes
# Out:
# order_id                    int64
# user_id                    object
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# #### Corrections

# %%
# I will try to do 2 at once somehow, I just needed an extra bracket 
df_ords[['order_id', 'order_number']] = df_ords[['order_id', 'order_number']].astype('str')

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# eval_set                   object
# order_number               object
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# ## Task 3

# %%
# task.3
# chaning the name of a column
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords
# Out:
#         order_id user_id eval_set order_number  orders_day_of_week  \
# 0        2539329       1    prior            1                   2
# 1        2398795       1    prior            2                   3
# 2         473747       1    prior            3                   3
# 3        2254736       1    prior            4                   4
# 4         431534       1    prior            5                   4
# ...          ...     ...      ...          ...                 ...
# 3421078  2266710  206209    prior           10                   5
# 3421079  1854736  206209    prior           11                   4
# 3421080   626363  206209    prior           12                   1
# 3421081  2977660  206209    prior           13                   1
# 3421082   272231  206209    train           14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# ...

# %% [markdown]
# ## Task 4

# %%
# task.4
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %%
#looks like 10am is the busiest hour

# %%
df_dep = pd.read_csv(os.path.join(path_2, 'departments.csv'), index_col = False)

# %%
df_dep
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# just changing the way the data is presentes but not acctually changing anything
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#overriding the way the data is presented 
df_dep_t = df_dep.T

# %%
# creating a new header
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# creating a new header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
#removing the first row in the dataframe
df_dep_t_new = df_dep_t[1:]

# %%
# add the new header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# creating a data dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
#inporting the products.csv
df_prods = pd.read_csv(os.path.join(path_2, 'products.csv'), index_col = False)

# %% [markdown]
# ## Task 5

# %%
# task 5 what does number 4 stand for
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# ## Task 6

# %%
# task 6 creating a subset of data with only breakfast items 
df_prods[df_prods['department_id']==14]
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %% [markdown]
# ## Task 7

# %%
# task 7 creat a subset for everything dinner
df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
df_dinner_par = df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]

# %%
df_dinner_par
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# ## Task 8

# %%
# task 8 this datafram has 49688 rows

# %%
print(df_ords['user_id'].unique())
# Out:
# ['1' '2' '3' ... '206207' '206208' '206209']

# %%
print(df_ords[df_ords['user_id'] == 1].head())
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# ##### I had a problem becouse I canhged the data typ to str which blocked me from using the code so i needed to convert it back to int

# %%
df_ords['user_id'] = df_ords['user_id'].astype('int')

# %%
# find out everything from the customer with the User_id 1
df_ords.loc[df_ords['user_id'] == 1]
# Out:
#    order_id  user_id eval_set order_number  orders_day_of_week  \
# 0   2539329        1    prior            1                   2
# 1   2398795        1    prior            2                   3
# 2    473747        1    prior            3                   3
# 3   2254736        1    prior            4                   4
# 4    431534        1    prior            5                   4
# 5   3367565        1    prior            6                   2
# 6    550135        1    prior            7                   1
# 7   3108588        1    prior            8                   1
# 8   2295261        1    prior            9                   1
# 9   2550362        1    prior           10                   4
# 10  1187899        1    train           11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %% [markdown]
# ## Task 9

# %%
# task 9 find out everything about user_id 1 
user_1 =df_ords[df_ords['user_id']==1]

# %%
user_1
# Out:
#    order_id  user_id eval_set order_number  orders_day_of_week  \
# 0   2539329        1    prior            1                   2
# 1   2398795        1    prior            2                   3
# 2    473747        1    prior            3                   3
# 3   2254736        1    prior            4                   4
# 4    431534        1    prior            5                   4
# 5   3367565        1    prior            6                   2
# 6    550135        1    prior            7                   1
# 7   3108588        1    prior            8                   1
# 8   2295261        1    prior            9                   1
# 9   2550362        1    prior           10                   4
# 10  1187899        1    train           11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %% [markdown]
# ## Task 10

# %%
#10 basic statments about the customer with user_id 1
user_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                11 non-null     object
#  1   user_id                 11 non-null     int64
#  2   eval_set                11 non-null     object
#  3   order_number            11 non-null     object
#  4   orders_day_of_week      11 non-null     int64
#  5   order_hour_of_day       11 non-null     int64
#  6   days_since_prior_order  10 non-null     float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 704.0+ bytes

# %%
user_1.describe()
# Out:
#        user_id  orders_day_of_week  order_hour_of_day  days_since_prior_order
# count     11.0           11.000000          11.000000               10.000000
# mean       1.0            2.636364          10.090909               19.000000
# std        0.0            1.286291           3.477198                9.030811
# min        1.0            1.000000           7.000000                0.000000
# 25%        1.0            1.500000           7.500000               14.250000
# 50%        1.0            3.000000           8.000000               19.500000
# 75%        1.0            4.000000          13.000000               26.250000
# max        1.0            4.000000          16.000000               30.000000

# %% [markdown]
# ## Task 12

# %%
# 12 I have already done this step while I went trough the reading and practice portion of 4.4

# %% [markdown]
# ##### Corrections

# %%
df_ords.to_csv(os.path.join(path,'orders_wrangled.csv'))

# %% [markdown]
# ## Task 14

# %%
# 13 saved in prepeared folder
df_dep_t_new.to_csv(os.path.join(path,'departments_wrangled.csv'))

# %%
total_rows, total_columns = df_ords.shape
print("Total number of rows:", total_rows)
print("Total number of columns:", total_columns)
# Out:
# Total number of rows: 3421083
# Total number of columns: 7

# %%
total_rows, total_columns = df_dep_t_new.shape
print("Total number of rows:", total_rows)
print("Total number of columns:", total_columns)
# Out:
# Total number of rows: 21
# Total number of columns: 1
