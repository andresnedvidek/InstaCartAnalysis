# %% [markdown]
# ## CareerFoundry Task 4.6

# %%
#Import Libraries/ Import the pandas, NumPy, and os libraries 
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Task 1

# %%
path = r'/Users/andrenedvidek/Desktop/Data Analaysis/CareerFoundry /Data Emersion /Task 4.3/02 Data copy/Original Data'

# %%
path_2 = r'/Users/andrenedvidek/Desktop/Data Analaysis/CareerFoundry /Data Emersion /Task 4.3/02 Data copy/Prepared Data'

# %%
df_ords_prior = pd.read_csv(os.path.join(path, 'orders_products_prior.csv'), index_col = False)

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_ords = pd.read_csv(os.path.join(path, 'orders.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path_2, 'orders_checked.csv'), index_col = False)

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 1                 1   2398795        1    prior             2
# 2                 2    473747        1    prior             3
# 3                 3   2254736        1    prior             4
# 4                 4    431534        1    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     NaN
# 1                         3                  7                    15.0
# ...

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_outer = df_ords.merge(df_ords_prior, on = 'order_id', how = 'outer',indicator = True)

# %%
df_merged_outer['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only       206209
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ## Task 2

# %%
df_merged_large.to_pickle(os.path.join(path_2,'orders_products_combined.pkl'))

# %%
total_rows, total_columns = df_merged_large.shape
print("Total number of rows:", total_rows)
print("Total number of columns:", total_columns)
# Out:
# Total number of rows: 32434489
# Total number of columns: 12

# %% [markdown]
# ### Task 3 Importing orders_products_combined.pkl

# %%
path = r'/Users/andrenedvidek/Desktop/Data Analaysis/CareerFoundry /Data Emersion /Task 4.3/02 Data copy/Prepared Data'

# %%
df_ords_prod = pd.read_pickle(os.path.join(path,'orders_products_combined.pkl'))

# %%
df_ords_prod
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                  0   2539329        1    prior             1
# 1                  0   2539329        1    prior             1
# 2                  0   2539329        1    prior             1
# 3                  0   2539329        1    prior             1
# 4                  0   2539329        1    prior             1
# ...              ...       ...      ...      ...           ...
# 32434484     3421081   2977660   206209    prior            13
# 32434485     3421081   2977660   206209    prior            13
# 32434486     3421081   2977660   206209    prior            13
# 32434487     3421081   2977660   206209    prior            13
# 32434488     3421081   2977660   206209    prior            13
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# ...

# %%
df_ords_prod.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ### Task 4 check the shape

# %%
# I know it won't be because I had to delete the 'Unnamed:0' Column
df_ords_prod.shape
# Out:
# (32434489, 11)

# %%
# this result makes scense

# %% [markdown]
# ### Task 5 merging datasets

# %%
df_prod_clean = pd.read_csv(os.path.join(path,'products_checked.csv'))

# %%
df_prod_clean
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_prod_clean.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_prod_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prod_clean.shape
# Out:
# (49672, 5)

# %%
# I will use the Product Id to merge the two dataframes 
# I will do a Left Join 

pd.merge(df_prod_clean,df_ords_prod, on=['product_id'], how = 'left', indicator=True,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 4
#       1 # I will use the Product Id to merge the two dataframes
#       2 # I will do a Left Join
# ----> 4 pd.merge(df_prod_clean,df_ords_prod, on=['product_id'], how = 'left', indicator=True,)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:183, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168 else:
#     169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#    (...)
#     181         validate=validate,
#     182     )
# --> 183     return op.get_result(copy=copy)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:881, in _MergeOperation.get_result(self, copy)
#     879 def get_result(self, copy: bool | None = True) -> DataFrame:
# ...

# %%
pd.merge(df_prod_clean, df_ords_prod, on=['product_id'], how='left', indicator='indicator_column_name')
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404865       49688      Fresh Foaming Cleanser        73             11
# 32404866       49688      Fresh Foaming Cleanser        73             11
# 32404867       49688      Fresh Foaming Cleanser        73             11
# 32404868       49688      Fresh Foaming Cleanser        73             11
# 32404869       49688      Fresh Foaming Cleanser        73             11
#
#           prices   order_id   user_id eval_set  order_number  \
# ...

# %%
df_merg_pro_ord=df_prod_clean.merge(df_ords_prod, on=['product_id'], how='left', indicator='indicator_column_name')

# %% [markdown]
# ### Task 6

# %%
df_merg_pro_ord['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### Task 7

# %%
df_merg_pro_ord.to_pickle(os.path.join(path,'Orders_products_merged.pkl'))

# %%
df_merg_pro_ord
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404865       49688      Fresh Foaming Cleanser        73             11
# 32404866       49688      Fresh Foaming Cleanser        73             11
# 32404867       49688      Fresh Foaming Cleanser        73             11
# 32404868       49688      Fresh Foaming Cleanser        73             11
# 32404869       49688      Fresh Foaming Cleanser        73             11
#
#           prices   order_id   user_id eval_set  order_number  \
# ...

# %%
total_rows, total_columns = df_merg_pro_ord.shape
print("Total number of rows:", total_rows)
print("Total number of columns:", total_columns)
# Out:
# Total number of rows: 32404870
# Total number of columns: 16
